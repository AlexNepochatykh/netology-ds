# %% [markdown]
# Виды распределений
# Загрузить таблицу и построить график распределений.
# Найти нормальное распределение.
# Таблица цен на дома в Бостоне

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Column description:
# * crim - per capita crime rate by town.
# * zn - proportion of residential land zoned for lots over 25,000 sq.ft.
# * indus - proportion of non-retail business acres per town.
# * chas - Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# * nox - nitrogen oxides concentration (parts per 10 million).
# * rm - average number of rooms per dwelling.
# * age - proportion of owner-occupied units built prior to 1940.
# * dis - weighted mean of distances to five Boston employment centres.
# * rad - index of accessibility to radial highways.
# * tax - full-value property-tax rate per  10,000 dollars
# * ptratio - pupil-teacher ratio by town.
# * black - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
# * lstat - lower status of the population (percent).
# * medv - median value of owner-occupied homes in $1000s.

# %%
df = pd.read_csv('data/boston_housing.csv')
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# std      0.702617   28.148861    2.105710    8.707259  168.537116    2.164946
# min      3.561000    2.900000    1.129600    1.000000  187.000000   12.600000
# 25%      5.885500   45.025000    2.100175    4.000000  279.000000   17.400000
# 50%      6.208500   77.500000    3.207450    5.000000  330.000000   19.050000
# 75%      6.623500   94.075000    5.188425   24.000000  666.000000   20.200000
# max      8.780000  100.000000   12.126500   24.000000  711.000000   22.000000
#
#             black       lstat        medv
# count  506.000000  506.000000  333.000000
# mean   356.674032   12.653063   22.768769
# std     91.294864    7.141062    9.173468
# min      0.320000    1.730000    5.000000
# 25%    375.377500    6.950000   17.400000
# 50%    391.440000   11.360000   21.600000
# 75%    396.225000   16.955000   25.000000
# max    396.900000   37.970000   50.000000

# %%
sns.pairplot(df);
# Out:
# C:\Users\mi\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\mi\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Судя про графикам, близки к нормальному распределению следующие значения:
# * proportion of non-retail business acres per town,
# * nitrogen oxides concentration (parts per 10 million),
# * average number of rooms per dwelling,
# * median value of owner-occupied homes in $1000s.

# %%
#Напишите код, который будет рисовать плотности распределений попарно
sns.pairplot(df[['indus','nox', 'rm', 'medv']]);

# %% [markdown]
# Загрузить таблицу iris. Нарисовать матрицу ковариаций попарно.
# Какие вектора из полученных метрик хорошо отделяют заданные выборки (можно провести прямую так, что два класса станут разными):
# iris_setosa и iris_versicolor?
# iris_versicolor и iris_virginica?
# iria_virginica и iris_setosa?

# %%
#sepal - чашелистник
#petal - лепесток
df_iris = pd.read_csv('data/iris.data')
df_iris.columns = ['sepal,length', 'sepal,width', 'petal,length', 'petal,width', 'class']
df_iris.head()
# Out:
#    sepal,length  sepal,width  petal,length  petal,width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df_iris['class'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        49
# Name: class, dtype: int64

# %%
sns.pairplot(df_iris, hue='class');

# %% [markdown]
# Сгенерировать 2 класса выборок с разными средними значениями m1=[−0.1, 1] и m2=[0.7, 0] и одинаковой матрицей ковариаций C=[[2,1],[1,2]]

# %%
cov1 = cov2 = np.array([[2, 1], [1, 2]] )
m1 = np.array([-0.1, 1])
m2 = np.array([0.7, 0])
N = 20000

# %% [markdown]
# Нарисовать контур (6 контуров ) распределений

# %%
from scipy.stats import multivariate_normal as mvn
nGrid = 500
x1, y1 = np.meshgrid(np.linspace(-6,6,nGrid),np.linspace(-6,6,nGrid))
s1 = np.column_stack([x1.flat, y1.flat])

x2, y2 = np.meshgrid(np.linspace(-6,6,nGrid),np.linspace(-6,6,nGrid))
s2 = np.column_stack([x2.flat, y2.flat])

plt.plot(m1[0], m1[1], 'bo')
plt.plot(m2[0], m2[1], 'ro')

# Графики распределений
z1 = mvn.pdf(s1, m1, cov1).reshape(x1.shape)
z2 = mvn.pdf(s2, m2, cov2).reshape(x2.shape)
# рисуем контуры для распределений
plt.contour(x1, y1, z1, 6, alpha=0.6)
plt.contour(x2, y2, z2, 6, alpha=0.6);

# %%
data1 = np.column_stack(np.random.multivariate_normal(m1, cov1, N))
data2 = np.column_stack(np.random.multivariate_normal(m2, cov2, N))

scatter1 = plt.plot(data1[0], data1[1], 'b.', alpha=0.3)
scatter2 = plt.plot(data2[0], data2[1], 'r.', alpha=0.3);

# %% [markdown]
# Посчитать вектор направления Фишера используя средние значения и матрицу ковариаций, и постройте график на плоскости.

# %%
from numpy.linalg import inv as inv
data1 = np.column_stack(np.random.multivariate_normal(m1, cov1, N))
data2 = np.column_stack(np.random.multivariate_normal(m2, cov2, N))

scatter1 = plt.plot(data1[0], data1[1], 'b.', alpha=0.3)
scatter2 = plt.plot(data2[0], data2[1], 'r.', alpha=0.3)
wF = inv(cov1 + cov2).dot(m1.T-m2.T)
xx = np.arange(-6,6,0.1)
yy = -xx.dot(wF[1]/wF[0])
fisher_line = plt.plot(xx, yy, 'r', linewidth=2)
plt.title("Выборки и вектор Фишера")
# Out:
# Text(0.5, 1.0, 'Выборки и вектор Фишера')

# %% [markdown]
# Сгенерируйте данные для двух выборок с разными средними значениями, но одинаковыми разбросами

# %%
proj1 = data1.T.dot(wF)
proj2 = data2.T.dot(wF)

min_scale = min([min(proj2), min(proj1)])
max_scale = max([max(proj2), max(proj1)])

plt.subplot(211)
plt.hist(proj1, 20, color='lightblue')
plt.title('Разброс спроецированных данных', fontsize=16)
plt.ylabel('Класс 1', fontsize=14)
plt.xlim([min_scale, max_scale])

plt.subplot(212)
plt.hist(proj2, 20, color='lightcoral')
plt.ylabel('Класс 2', fontsize=14)
plt.xlim([min_scale, max_scale])

plt.show()

# %% [markdown]
# Сгенерируйте 20 данных и сравните с предыдущим графиком. Что поменялось? Какое это распределение может быть?
# Можно ли отнести эти данные к распределению Стьюдента? Почему?

# %%
N = 20

# %%
data1 = np.column_stack(np.random.multivariate_normal(m1, cov1, N))
data2 = np.column_stack(np.random.multivariate_normal(m2, cov2, N))

scatter1 = plt.plot(data1[0], data1[1], 'b.', alpha=0.3)
scatter2 = plt.plot(data2[0], data2[1], 'r.', alpha=0.3)
wF = inv(cov1 + cov2).dot(m1.T-m2.T)
xx = np.arange(-6,6,0.1)
yy = -xx.dot(wF[1]/wF[0])
fisher_line = plt.plot(xx, yy, 'r', linewidth=2)
plt.title("Выборки и вектор Фишера")
# Out:
# Text(0.5, 1.0, 'Выборки и вектор Фишера')

# %%
proj1 = data1.T.dot(wF)
proj2 = data2.T.dot(wF)

min_scale = min([min(proj2), min(proj1)])
max_scale = max([max(proj2), max(proj1)])

plt.subplot(211)
plt.hist(proj1, 20, color='lightblue')
plt.title('Разброс спроецированных данных', fontsize=16)
plt.ylabel('Класс 1', fontsize=14)
plt.xlim([min_scale, max_scale])

plt.subplot(212)
plt.hist(proj2, 20, color='lightcoral')
plt.ylabel('Класс 2', fontsize=14)
plt.xlim([min_scale, max_scale])

plt.show()

# %% [markdown]
# Данных довольно мало, поэтому отнести данное распределение к распределению Фишера не представляется возможным.
#
# Для сравнения - при N = 20000 распределение очень близко к нормальному.
