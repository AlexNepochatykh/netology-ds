# %% [markdown]
# # Dogs vs. Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
import warnings

# %%
IMG_SIZE = (224, 224)  # размер входного изображения сети

# %% [markdown]
# ## Функции загрузки данных

# %%
import re
from random import shuffle
from glob import glob

train_files = glob('data/cat_and_dogs/train/*.jpg')
test_files = glob('data/cat_and_dogs/test/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = load_img(path, target_size=target_size)  # загрузка и масштабирование изображения
    array = img_to_array(img)
    return preprocess_input(array)  # предобработка для VGG16

# генератор для последовательного чтения обучающих данных с диска
def fit_generator(files, batch_size=32):
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if re.match('.*/dog\.\d', path) else 0. for path in files[i:j]])
            yield (x, y)

# генератор последовательного чтения тестовых данных с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %%
len(test_files)
# Out:
# 12500

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(i//5+1, 5, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%s' % path.split('/')[-1]);

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
for i, path in enumerate(test_files[:10], 1):
    subplot = fig.add_subplot(i//5+1, 5, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%s' % path.split('/')[-1]);

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model -  объект класса keras.models.Model (Functional Model)
base_model = VGG16(include_top = False,
                   weights = 'imagenet',
                   input_shape = (IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

# %%
base_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
x = base_model.layers[-5].output
x = keras.layers.Flatten()(x)
x = keras.layers.Dense(1,  # один выход
                activation='sigmoid',  # функция активации  
                kernel_regularizer=keras.regularizers.l1(1e-4))(x)
model = Model(inputs=base_model.input, outputs=x)

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 100353
# =================================================================
# Total params: 7,735,617
# Trainable params: 100,353
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
shuffle(train_files)  # перемешиваем обучающую выборку

train_val_split = 100  # число изображений в валидационной выборке

validation_data = next(fit_generator(train_files[:train_val_split], train_val_split))

# запускаем процесс обучения
model.fit_generator(fit_generator(train_files[train_val_split:]),  # данные читаем функцией-генератором
        steps_per_epoch=10,  # число вызовов генератора за эпоху
        epochs=100,  # число эпох обучения
        validation_data=validation_data)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 32s 324ms/sample - loss: 0.0239 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 1.0405 - acc: 0.9344 - val_loss: 0.0239 - val_acc: 1.0000
# Epoch 2/100
# 100/100 [==============================] - 30s 298ms/sample - loss: 0.0250 - acc: 1.0000
# 10/10 [==============================] - 123s 12s/step - loss: 0.0241 - acc: 1.0000 - val_loss: 0.0250 - val_acc: 1.0000
# Epoch 3/100
# 100/100 [==============================] - 28s 283ms/sample - loss: 0.0256 - acc: 1.0000
# 10/10 [==============================] - 119s 12s/step - loss: 0.0253 - acc: 1.0000 - val_loss: 0.0256 - val_acc: 1.0000
# Epoch 4/100
# 100/100 [==============================] - 32s 319ms/sample - loss: 0.0259 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0257 - acc: 1.0000 - val_loss: 0.0259 - val_acc: 1.0000
# Epoch 5/100
# 100/100 [==============================] - 31s 312ms/sample - loss: 0.0260 - acc: 1.0000
# 10/10 [==============================] - 138s 14s/step - loss: 0.0259 - acc: 1.0000 - val_loss: 0.0260 - val_acc: 1.0000
# Epoch 6/100
# 100/100 [==============================] - 30s 302ms/sample - loss: 0.0259 - acc: 1.0000
# 10/10 [==============================] - 126s 13s/step - loss: 0.0259 - acc: 1.0000 - val_loss: 0.0259 - val_acc: 1.0000
# Epoch 7/100
# 100/100 [==============================] - 28s 278ms/sample - loss: 0.0259 - acc: 1.0000
# 10/10 [==============================] - 120s 12s/step - loss: 0.0259 - acc: 1.0000 - val_loss: 0.0259 - val_acc: 1.0000
# Epoch 8/100
# 100/100 [==============================] - 28s 283ms/sample - loss: 0.0258 - acc: 1.0000
# 10/10 [==============================] - 118s 12s/step - loss: 0.0258 - acc: 1.0000 - val_loss: 0.0258 - val_acc: 1.0000
# Epoch 9/100
# 100/100 [==============================] - 27s 274ms/sample - loss: 0.0257 - acc: 1.0000
# 10/10 [==============================] - 119s 12s/step - loss: 0.0257 - acc: 1.0000 - val_loss: 0.0257 - val_acc: 1.0000
# Epoch 10/100
# 100/100 [==============================] - 27s 271ms/sample - loss: 0.0256 - acc: 1.0000
# 10/10 [==============================] - 115s 12s/step - loss: 0.0257 - acc: 1.0000 - val_loss: 0.0256 - val_acc: 1.0000
# Epoch 11/100
# 100/100 [==============================] - 30s 298ms/sample - loss: 0.0256 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0256 - acc: 1.0000 - val_loss: 0.0256 - val_acc: 1.0000
# Epoch 12/100
# 100/100 [==============================] - 29s 292ms/sample - loss: 0.0255 - acc: 1.0000
# 10/10 [==============================] - 124s 12s/step - loss: 0.0255 - acc: 1.0000 - val_loss: 0.0255 - val_acc: 1.0000
# Epoch 13/100
# 100/100 [==============================] - 31s 308ms/sample - loss: 0.0254 - acc: 1.0000
# 10/10 [==============================] - 126s 13s/step - loss: 0.0254 - acc: 1.0000 - val_loss: 0.0254 - val_acc: 1.0000
# Epoch 14/100
# 100/100 [==============================] - 31s 313ms/sample - loss: 0.0253 - acc: 1.0000
# 10/10 [==============================] - 134s 13s/step - loss: 0.0253 - acc: 1.0000 - val_loss: 0.0253 - val_acc: 1.0000
# Epoch 15/100
# 100/100 [==============================] - 32s 320ms/sample - loss: 0.0252 - acc: 1.0000
# 10/10 [==============================] - 134s 13s/step - loss: 0.0253 - acc: 1.0000 - val_loss: 0.0252 - val_acc: 1.0000
# Epoch 16/100
# 100/100 [==============================] - 32s 317ms/sample - loss: 0.0251 - acc: 1.0000
# 10/10 [==============================] - 137s 14s/step - loss: 0.0252 - acc: 1.0000 - val_loss: 0.0251 - val_acc: 1.0000
# Epoch 17/100
# 100/100 [==============================] - 32s 325ms/sample - loss: 0.0250 - acc: 1.0000
# 10/10 [==============================] - 136s 14s/step - loss: 0.0251 - acc: 1.0000 - val_loss: 0.0250 - val_acc: 1.0000
# Epoch 18/100
# 100/100 [==============================] - 32s 321ms/sample - loss: 0.0250 - acc: 1.0000
# 10/10 [==============================] - 136s 14s/step - loss: 0.0250 - acc: 1.0000 - val_loss: 0.0250 - val_acc: 1.0000
# Epoch 19/100
# 100/100 [==============================] - 31s 312ms/sample - loss: 0.0249 - acc: 1.0000
# 10/10 [==============================] - 132s 13s/step - loss: 0.0249 - acc: 1.0000 - val_loss: 0.0249 - val_acc: 1.0000
# Epoch 20/100
# 100/100 [==============================] - 32s 324ms/sample - loss: 0.0248 - acc: 1.0000
# 10/10 [==============================] - 136s 14s/step - loss: 0.0248 - acc: 1.0000 - val_loss: 0.0248 - val_acc: 1.0000
# Epoch 21/100
# 100/100 [==============================] - 31s 309ms/sample - loss: 0.0247 - acc: 1.0000
# 10/10 [==============================] - 139s 14s/step - loss: 0.0247 - acc: 1.0000 - val_loss: 0.0247 - val_acc: 1.0000
# Epoch 22/100
# 100/100 [==============================] - 32s 322ms/sample - loss: 0.0246 - acc: 1.0000
# 10/10 [==============================] - 135s 14s/step - loss: 0.0247 - acc: 1.0000 - val_loss: 0.0246 - val_acc: 1.0000
# Epoch 23/100
# 100/100 [==============================] - 29s 288ms/sample - loss: 0.0245 - acc: 1.0000
# 10/10 [==============================] - 128s 13s/step - loss: 0.0246 - acc: 1.0000 - val_loss: 0.0245 - val_acc: 1.0000
# Epoch 24/100
# 100/100 [==============================] - 28s 280ms/sample - loss: 0.0244 - acc: 1.0000
# 10/10 [==============================] - 118s 12s/step - loss: 0.0245 - acc: 1.0000 - val_loss: 0.0244 - val_acc: 1.0000
# Epoch 25/100
# 100/100 [==============================] - 30s 299ms/sample - loss: 0.0244 - acc: 1.0000
# 10/10 [==============================] - 121s 12s/step - loss: 0.0244 - acc: 1.0000 - val_loss: 0.0244 - val_acc: 1.0000
# Epoch 26/100
# 100/100 [==============================] - 30s 298ms/sample - loss: 0.0243 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0243 - acc: 1.0000 - val_loss: 0.0243 - val_acc: 1.0000
# Epoch 27/100
# 100/100 [==============================] - 30s 305ms/sample - loss: 0.0242 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0242 - acc: 1.0000 - val_loss: 0.0242 - val_acc: 1.0000
# Epoch 28/100
# 100/100 [==============================] - 30s 296ms/sample - loss: 0.0241 - acc: 1.0000
# 10/10 [==============================] - 126s 13s/step - loss: 0.0241 - acc: 1.0000 - val_loss: 0.0241 - val_acc: 1.0000
# Epoch 29/100
# 100/100 [==============================] - 29s 291ms/sample - loss: 0.0240 - acc: 1.0000
# 10/10 [==============================] - 125s 13s/step - loss: 0.0240 - acc: 1.0000 - val_loss: 0.0240 - val_acc: 1.0000
# Epoch 30/100
# 100/100 [==============================] - 31s 307ms/sample - loss: 0.0239 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0239 - acc: 1.0000 - val_loss: 0.0239 - val_acc: 1.0000
# Epoch 31/100
# 100/100 [==============================] - 29s 293ms/sample - loss: 0.0238 - acc: 1.0000
# 10/10 [==============================] - 126s 13s/step - loss: 0.0239 - acc: 1.0000 - val_loss: 0.0238 - val_acc: 1.0000
# Epoch 32/100
# 100/100 [==============================] - 29s 293ms/sample - loss: 0.0237 - acc: 1.0000
# 10/10 [==============================] - 123s 12s/step - loss: 0.0238 - acc: 1.0000 - val_loss: 0.0237 - val_acc: 1.0000
# Epoch 33/100
# 100/100 [==============================] - 29s 289ms/sample - loss: 0.0236 - acc: 1.0000
# 10/10 [==============================] - 122s 12s/step - loss: 0.0237 - acc: 1.0000 - val_loss: 0.0236 - val_acc: 1.0000
# Epoch 34/100
# 100/100 [==============================] - 28s 280ms/sample - loss: 0.0235 - acc: 1.0000
# 10/10 [==============================] - 122s 12s/step - loss: 0.0236 - acc: 1.0000 - val_loss: 0.0235 - val_acc: 1.0000
# Epoch 35/100
# 100/100 [==============================] - 29s 289ms/sample - loss: 0.0235 - acc: 1.0000
# 10/10 [==============================] - 120s 12s/step - loss: 0.0235 - acc: 1.0000 - val_loss: 0.0235 - val_acc: 1.0000
# Epoch 36/100
# 100/100 [==============================] - 29s 293ms/sample - loss: 0.0234 - acc: 1.0000
# 10/10 [==============================] - 122s 12s/step - loss: 0.0234 - acc: 1.0000 - val_loss: 0.0234 - val_acc: 1.0000
# Epoch 37/100
# 100/100 [==============================] - 31s 306ms/sample - loss: 0.0233 - acc: 1.0000
# 10/10 [==============================] - 130s 13s/step - loss: 0.0233 - acc: 1.0000 - val_loss: 0.0233 - val_acc: 1.0000
# Epoch 38/100
# 100/100 [==============================] - 30s 303ms/sample - loss: 0.0232 - acc: 1.0000
# 10/10 [==============================] - 128s 13s/step - loss: 0.0232 - acc: 1.0000 - val_loss: 0.0232 - val_acc: 1.0000
# Epoch 39/100
# 100/100 [==============================] - 31s 305ms/sample - loss: 0.0231 - acc: 1.0000
# 10/10 [==============================] - 128s 13s/step - loss: 0.0231 - acc: 1.0000 - val_loss: 0.0231 - val_acc: 1.0000
# Epoch 40/100
# 100/100 [==============================] - 30s 304ms/sample - loss: 0.0230 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0230 - acc: 1.0000 - val_loss: 0.0230 - val_acc: 1.0000
# Epoch 41/100
# 100/100 [==============================] - 30s 299ms/sample - loss: 0.0229 - acc: 1.0000
# 10/10 [==============================] - 129s 13s/step - loss: 0.0229 - acc: 1.0000 - val_loss: 0.0229 - val_acc: 1.0000
# Epoch 42/100
# 100/100 [==============================] - 30s 299ms/sample - loss: 0.0229 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0229 - acc: 1.0000 - val_loss: 0.0229 - val_acc: 1.0000
# Epoch 43/100
# 100/100 [==============================] - 30s 303ms/sample - loss: 0.0227 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0228 - acc: 1.0000 - val_loss: 0.0227 - val_acc: 1.0000
# Epoch 44/100
# 100/100 [==============================] - 30s 299ms/sample - loss: 0.0226 - acc: 1.0000
# 10/10 [==============================] - 127s 13s/step - loss: 0.0227 - acc: 1.0000 - val_loss: 0.0226 - val_acc: 1.0000
# Epoch 45/100
# 100/100 [==============================] - 30s 304ms/sample - loss: 0.0225 - acc: 1.0000
# 10/10 [==============================] - 126s 13s/step - loss: 0.0226 - acc: 1.0000 - val_loss: 0.0225 - val_acc: 1.0000
# Epoch 46/100
# 100/100 [==============================] - 30s 300ms/sample - loss: 0.0225 - acc: 1.0000
# 10/10 [==============================] - 126s 13s/step - loss: 0.0225 - acc: 1.0000 - val_loss: 0.0225 - val_acc: 1.0000
# Epoch 47/100
# 100/100 [==============================] - 31s 312ms/sample - loss: 0.0224 - acc: 1.0000
# 10/10 [==============================] - 128s 13s/step - loss: 0.0224 - acc: 1.0000 - val_loss: 0.0224 - val_acc: 1.0000
# Epoch 48/100
# 100/100 [==============================] - 31s 309ms/sample - loss: 0.0223 - acc: 1.0000
# 10/10 [==============================] - 128s 13s/step - loss: 0.0223 - acc: 1.0000 - val_loss: 0.0223 - val_acc: 1.0000
# Epoch 49/100
# 100/100 [==============================] - 31s 312ms/sample - loss: 0.0222 - acc: 1.0000
# 10/10 [==============================] - 130s 13s/step - loss: 0.0222 - acc: 1.0000 - val_loss: 0.0222 - val_acc: 1.0000
# Epoch 50/100
# 100/100 [==============================] - 31s 310ms/sample - loss: 0.0221 - acc: 1.0000
# 10/10 [==============================] - 130s 13s/step - loss: 0.0221 - acc: 1.0000 - val_loss: 0.0221 - val_acc: 1.0000
# Epoch 51/100
# 100/100 [==============================] - 30s 298ms/sample - loss: 0.0220 - acc: 1.0000
# 10/10 [==============================] - 126s 13s/step - loss: 0.0220 - acc: 1.0000 - val_loss: 0.0220 - val_acc: 1.0000
# Epoch 52/100
#  7/10 [====================>.........] - ETA: 29s - loss: 0.0220 - acc: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-879d3319d57f> in <module>
#       9         steps_per_epoch=10,  # число вызовов генератора за эпоху
#      10         epochs=100,  # число эпох обучения
# ---> 11         validation_data=validation_data)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1424         use_multiprocessing=use_multiprocessing,
#    1425         shuffle=shuffle,
# -> 1426         initial_epoch=initial_epoch)
#    1427
#    1428   def evaluate_generator(self,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, **kwargs)
#     189       progbar.on_batch_begin(step, batch_logs)
#     190
# --> 191       batch_outs = batch_function(*batch_data)
#     192       if not isinstance(batch_outs, list):
#     193         batch_outs = [batch_outs]
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1189       else:
#    1190         self._make_fit_function()
# -> 1191         outputs = self._fit_function(ins)  # pylint: disable=not-callable
#    1192
#    1193     if reset_metrics:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model.save('cats-dogs-vgg16.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_files
# Out:
# ['data/cat_and_dogs/test\\1.jpg',
#  'data/cat_and_dogs/test\\10.jpg',
#  'data/cat_and_dogs/test\\100.jpg',
#  'data/cat_and_dogs/test\\1000.jpg',
#  'data/cat_and_dogs/test\\10000.jpg',
#  'data/cat_and_dogs/test\\10001.jpg',
#  'data/cat_and_dogs/test\\10002.jpg',
#  'data/cat_and_dogs/test\\10003.jpg',
#  'data/cat_and_dogs/test\\10004.jpg',
#  'data/cat_and_dogs/test\\10005.jpg',
#  'data/cat_and_dogs/test\\10006.jpg',
#  'data/cat_and_dogs/test\\10007.jpg',
#  'data/cat_and_dogs/test\\10008.jpg',
#  'data/cat_and_dogs/test\\10009.jpg',
#  'data/cat_and_dogs/test\\1001.jpg',
#  'data/cat_and_dogs/test\\10010.jpg',
#  'data/cat_and_dogs/test\\10011.jpg',
#  'data/cat_and_dogs/test\\10012.jpg',
#  'data/cat_and_dogs/test\\10013.jpg',
#  'data/cat_and_dogs/test\\10014.jpg',
#  'data/cat_and_dogs/test\\10015.jpg',
#  'data/cat_and_dogs/test\\10016.jpg',
#  'data/cat_and_dogs/test\\10017.jpg',
#  'data/cat_and_dogs/test\\10018.jpg',
#  'data/cat_and_dogs/test\\10019.jpg',
#  'data/cat_and_dogs/test\\1002.jpg',
#  'data/cat_and_dogs/test\\10020.jpg',
#  'data/cat_and_dogs/test\\10021.jpg',
#  'data/cat_and_dogs/test\\10022.jpg',
#  'data/cat_and_dogs/test\\10023.jpg',
#  'data/cat_and_dogs/test\\10024.jpg',
#  'data/cat_and_dogs/test\\10025.jpg',
#  'data/cat_and_dogs/test\\10026.jpg',
#  'data/cat_and_dogs/test\\10027.jpg',
#  'data/cat_and_dogs/test\\10028.jpg',
#  'data/cat_and_dogs/test\\10029.jpg',
#  'data/cat_and_dogs/test\\1003.jpg',
#  'data/cat_and_dogs/test\\10030.jpg',
#  'data/cat_and_dogs/test\\10031.jpg',
#  'data/cat_and_dogs/test\\10032.jpg',
#  'data/cat_and_dogs/test\\10033.jpg',
#  'data/cat_and_dogs/test\\10034.jpg',
#  'data/cat_and_dogs/test\\10035.jpg',
#  'data/cat_and_dogs/test\\10036.jpg',
#  'data/cat_and_dogs/test\\10037.jpg',
#  'data/cat_and_dogs/test\\10038.jpg',
#  'data/cat_and_dogs/test\\10039.jpg',
#  'data/cat_and_dogs/test\\1004.jpg',
#  'data/cat_and_dogs/test\\10040.jpg',
#  'data/cat_and_dogs/test\\10041.jpg',
#  'data/cat_and_dogs/test\\10042.jpg',
#  'data/cat_and_dogs/test\\10043.jpg',
#  'data/cat_and_dogs/test\\10044.jpg',
#  'data/cat_and_dogs/test\\10045.jpg',
#  'data/cat_and_dogs/test\\10046.jpg',
#  'data/cat_and_dogs/test\\10047.jpg',
#  'data/cat_and_dogs/test\\10048.jpg',
#  'data/cat_and_dogs/test\\10049.jpg',
#  'data/cat_and_dogs/test\\1005.jpg',
#  'data/cat_and_dogs/test\\10050.jpg',
#  'data/cat_and_dogs/test\\10051.jpg',
#  'data/cat_and_dogs/test\\10052.jpg',
#  'data/cat_and_dogs/test\\10053.jpg',
#  'data/cat_and_dogs/test\\10054.jpg',
#  'data/cat_and_dogs/test\\10055.jpg',
#  'data/cat_and_dogs/test\\10056.jpg',
#  'data/cat_and_dogs/test\\10057.jpg',
#  'data/cat_and_dogs/test\\10058.jpg',
#  'data/cat_and_dogs/test\\10059.jpg',
#  'data/cat_and_dogs/test\\1006.jpg',
#  'data/cat_and_dogs/test\\10060.jpg',
#  'data/cat_and_dogs/test\\10061.jpg',
#  'data/cat_and_dogs/test\\10062.jpg',
#  'data/cat_and_dogs/test\\10063.jpg',
#  'data/cat_and_dogs/test\\10064.jpg',
#  'data/cat_and_dogs/test\\10065.jpg',
#  'data/cat_and_dogs/test\\10066.jpg',
#  'data/cat_and_dogs/test\\10067.jpg',
#  'data/cat_and_dogs/test\\10068.jpg',
#  'data/cat_and_dogs/test\\10069.jpg',
#  'data/cat_and_dogs/test\\1007.jpg',
#  'data/cat_and_dogs/test\\10070.jpg',
#  'data/cat_and_dogs/test\\10071.jpg',
#  'data/cat_and_dogs/test\\10072.jpg',
#  'data/cat_and_dogs/test\\10073.jpg',
#  'data/cat_and_dogs/test\\10074.jpg',
#  'data/cat_and_dogs/test\\10075.jpg',
#  'data/cat_and_dogs/test\\10076.jpg',
#  'data/cat_and_dogs/test\\10077.jpg',
#  'data/cat_and_dogs/test\\10078.jpg',
#  'data/cat_and_dogs/test\\10079.jpg',
#  'data/cat_and_dogs/test\\1008.jpg',
#  'data/cat_and_dogs/test\\10080.jpg',
#  'data/cat_and_dogs/test\\10081.jpg',
#  'data/cat_and_dogs/test\\10082.jpg',
#  'data/cat_and_dogs/test\\10083.jpg',
#  'data/cat_and_dogs/test\\10084.jpg',
#  'data/cat_and_dogs/test\\10085.jpg',
#  'data/cat_and_dogs/test\\10086.jpg',
#  'data/cat_and_dogs/test\\10087.jpg',
#  'data/cat_and_dogs/test\\10088.jpg',
#  'data/cat_and_dogs/test\\10089.jpg',
#  'data/cat_and_dogs/test\\1009.jpg',
#  'data/cat_and_dogs/test\\10090.jpg',
#  'data/cat_and_dogs/test\\10091.jpg',
#  'data/cat_and_dogs/test\\10092.jpg',
#  'data/cat_and_dogs/test\\10093.jpg',
#  'data/cat_and_dogs/test\\10094.jpg',
#  'data/cat_and_dogs/test\\10095.jpg',
#  'data/cat_and_dogs/test\\10096.jpg',
#  'data/cat_and_dogs/test\\10097.jpg',
#  'data/cat_and_dogs/test\\10098.jpg',
#  'data/cat_and_dogs/test\\10099.jpg',
#  'data/cat_and_dogs/test\\101.jpg',
#  'data/cat_and_dogs/test\\1010.jpg',
#  'data/cat_and_dogs/test\\10100.jpg',
#  'data/cat_and_dogs/test\\10101.jpg',
#  'data/cat_and_dogs/test\\10102.jpg',
#  'data/cat_and_dogs/test\\10103.jpg',
#  'data/cat_and_dogs/test\\10104.jpg',
#  'data/cat_and_dogs/test\\10105.jpg',
#  'data/cat_and_dogs/test\\10106.jpg',
#  'data/cat_and_dogs/test\\10107.jpg',
#  'data/cat_and_dogs/test\\10108.jpg',
#  'data/cat_and_dogs/test\\10109.jpg',
#  'data/cat_and_dogs/test\\1011.jpg',
#  'data/cat_and_dogs/test\\10110.jpg',
#  'data/cat_and_dogs/test\\10111.jpg',
#  'data/cat_and_dogs/test\\10112.jpg',
#  'data/cat_and_dogs/test\\10113.jpg',
#  'data/cat_and_dogs/test\\10114.jpg',
#  'data/cat_and_dogs/test\\10115.jpg',
#  'data/cat_and_dogs/test\\10116.jpg',
#  'data/cat_and_dogs/test\\10117.jpg',
#  'data/cat_and_dogs/test\\10118.jpg',
#  'data/cat_and_dogs/test\\10119.jpg',
#  'data/cat_and_dogs/test\\1012.jpg',
#  'data/cat_and_dogs/test\\10120.jpg',
#  'data/cat_and_dogs/test\\10121.jpg',
#  'data/cat_and_dogs/test\\10122.jpg',
#  'data/cat_and_dogs/test\\10123.jpg',
#  'data/cat_and_dogs/test\\10124.jpg',
#  'data/cat_and_dogs/test\\10125.jpg',
#  'data/cat_and_dogs/test\\10126.jpg',
#  'data/cat_and_dogs/test\\10127.jpg',
#  'data/cat_and_dogs/test\\10128.jpg',
#  'data/cat_and_dogs/test\\10129.jpg',
#  'data/cat_and_dogs/test\\1013.jpg',
#  'data/cat_and_dogs/test\\10130.jpg',
#  'data/cat_and_dogs/test\\10131.jpg',
#  'data/cat_and_dogs/test\\10132.jpg',
#  'data/cat_and_dogs/test\\10133.jpg',
#  'data/cat_and_dogs/test\\10134.jpg',
#  'data/cat_and_dogs/test\\10135.jpg',
#  'data/cat_and_dogs/test\\10136.jpg',
#  'data/cat_and_dogs/test\\10137.jpg',
#  'data/cat_and_dogs/test\\10138.jpg',
#  'data/cat_and_dogs/test\\10139.jpg',
#  'data/cat_and_dogs/test\\1014.jpg',
#  'data/cat_and_dogs/test\\10140.jpg',
#  'data/cat_and_dogs/test\\10141.jpg',
#  'data/cat_and_dogs/test\\10142.jpg',
#  'data/cat_and_dogs/test\\10143.jpg',
#  'data/cat_and_dogs/test\\10144.jpg',
#  'data/cat_and_dogs/test\\10145.jpg',
#  'data/cat_and_dogs/test\\10146.jpg',
#  'data/cat_and_dogs/test\\10147.jpg',
#  'data/cat_and_dogs/test\\10148.jpg',
#  'data/cat_and_dogs/test\\10149.jpg',
#  'data/cat_and_dogs/test\\1015.jpg',
#  'data/cat_and_dogs/test\\10150.jpg',
#  'data/cat_and_dogs/test\\10151.jpg',
#  'data/cat_and_dogs/test\\10152.jpg',
#  'data/cat_and_dogs/test\\10153.jpg',
#  'data/cat_and_dogs/test\\10154.jpg',
#  'data/cat_and_dogs/test\\10155.jpg',
#  'data/cat_and_dogs/test\\10156.jpg',
#  'data/cat_and_dogs/test\\10157.jpg',
#  'data/cat_and_dogs/test\\10158.jpg',
#  'data/cat_and_dogs/test\\10159.jpg',
#  'data/cat_and_dogs/test\\1016.jpg',
#  'data/cat_and_dogs/test\\10160.jpg',
#  'data/cat_and_dogs/test\\10161.jpg',
#  'data/cat_and_dogs/test\\10162.jpg',
#  'data/cat_and_dogs/test\\10163.jpg',
#  'data/cat_and_dogs/test\\10164.jpg',
#  'data/cat_and_dogs/test\\10165.jpg',
#  'data/cat_and_dogs/test\\10166.jpg',
#  'data/cat_and_dogs/test\\10167.jpg',
#  'data/cat_and_dogs/test\\10168.jpg',
#  'data/cat_and_dogs/test\\10169.jpg',
#  'data/cat_and_dogs/test\\1017.jpg',
#  'data/cat_and_dogs/test\\10170.jpg',
#  'data/cat_and_dogs/test\\10171.jpg',
#  'data/cat_and_dogs/test\\10172.jpg',
#  'data/cat_and_dogs/test\\10173.jpg',
#  'data/cat_and_dogs/test\\10174.jpg',
#  'data/cat_and_dogs/test\\10175.jpg',
#  'data/cat_and_dogs/test\\10176.jpg',
#  'data/cat_and_dogs/test\\10177.jpg',
#  'data/cat_and_dogs/test\\10178.jpg',
#  'data/cat_and_dogs/test\\10179.jpg',
#  'data/cat_and_dogs/test\\1018.jpg',
#  'data/cat_and_dogs/test\\10180.jpg',
#  'data/cat_and_dogs/test\\10181.jpg',
#  'data/cat_and_dogs/test\\10182.jpg',
#  'data/cat_and_dogs/test\\10183.jpg',
#  'data/cat_and_dogs/test\\10184.jpg',
#  'data/cat_and_dogs/test\\10185.jpg',
#  'data/cat_and_dogs/test\\10186.jpg',
#  'data/cat_and_dogs/test\\10187.jpg',
#  'data/cat_and_dogs/test\\10188.jpg',
#  'data/cat_and_dogs/test\\10189.jpg',
#  'data/cat_and_dogs/test\\1019.jpg',
#  'data/cat_and_dogs/test\\10190.jpg',
#  'data/cat_and_dogs/test\\10191.jpg',
#  'data/cat_and_dogs/test\\10192.jpg',
#  'data/cat_and_dogs/test\\10193.jpg',
#  'data/cat_and_dogs/test\\10194.jpg',
#  'data/cat_and_dogs/test\\10195.jpg',
#  'data/cat_and_dogs/test\\10196.jpg',
#  'data/cat_and_dogs/test\\10197.jpg',
#  'data/cat_and_dogs/test\\10198.jpg',
#  'data/cat_and_dogs/test\\10199.jpg',
#  'data/cat_and_dogs/test\\102.jpg',
#  'data/cat_and_dogs/test\\1020.jpg',
#  'data/cat_and_dogs/test\\10200.jpg',
#  'data/cat_and_dogs/test\\10201.jpg',
#  'data/cat_and_dogs/test\\10202.jpg',
#  'data/cat_and_dogs/test\\10203.jpg',
#  'data/cat_and_dogs/test\\10204.jpg',
#  'data/cat_and_dogs/test\\10205.jpg',
#  'data/cat_and_dogs/test\\10206.jpg',
#  'data/cat_and_dogs/test\\10207.jpg',
#  'data/cat_and_dogs/test\\10208.jpg',
#  'data/cat_and_dogs/test\\10209.jpg',
#  'data/cat_and_dogs/test\\1021.jpg',
#  'data/cat_and_dogs/test\\10210.jpg',
#  'data/cat_and_dogs/test\\10211.jpg',
#  'data/cat_and_dogs/test\\10212.jpg',
#  'data/cat_and_dogs/test\\10213.jpg',
#  'data/cat_and_dogs/test\\10214.jpg',
#  'data/cat_and_dogs/test\\10215.jpg',
#  'data/cat_and_dogs/test\\10216.jpg',
#  'data/cat_and_dogs/test\\10217.jpg',
#  'data/cat_and_dogs/test\\10218.jpg',
#  'data/cat_and_dogs/test\\10219.jpg',
#  'data/cat_and_dogs/test\\1022.jpg',
#  'data/cat_and_dogs/test\\10220.jpg',
#  'data/cat_and_dogs/test\\10221.jpg',
#  'data/cat_and_dogs/test\\10222.jpg',
#  'data/cat_and_dogs/test\\10223.jpg',
#  'data/cat_and_dogs/test\\10224.jpg',
#  'data/cat_and_dogs/test\\10225.jpg',
#  'data/cat_and_dogs/test\\10226.jpg',
#  'data/cat_and_dogs/test\\10227.jpg',
#  'data/cat_and_dogs/test\\10228.jpg',
#  'data/cat_and_dogs/test\\10229.jpg',
#  'data/cat_and_dogs/test\\1023.jpg',
#  'data/cat_and_dogs/test\\10230.jpg',
#  'data/cat_and_dogs/test\\10231.jpg',
#  'data/cat_and_dogs/test\\10232.jpg',
#  'data/cat_and_dogs/test\\10233.jpg',
#  'data/cat_and_dogs/test\\10234.jpg',
#  'data/cat_and_dogs/test\\10235.jpg',
#  'data/cat_and_dogs/test\\10236.jpg',
#  'data/cat_and_dogs/test\\10237.jpg',
#  'data/cat_and_dogs/test\\10238.jpg',
#  'data/cat_and_dogs/test\\10239.jpg',
#  'data/cat_and_dogs/test\\1024.jpg',
#  'data/cat_and_dogs/test\\10240.jpg',
#  'data/cat_and_dogs/test\\10241.jpg',
#  'data/cat_and_dogs/test\\10242.jpg',
#  'data/cat_and_dogs/test\\10243.jpg',
#  'data/cat_and_dogs/test\\10244.jpg',
#  'data/cat_and_dogs/test\\10245.jpg',
#  'data/cat_and_dogs/test\\10246.jpg',
#  'data/cat_and_dogs/test\\10247.jpg',
#  'data/cat_and_dogs/test\\10248.jpg',
#  'data/cat_and_dogs/test\\10249.jpg',
#  'data/cat_and_dogs/test\\1025.jpg',
#  'data/cat_and_dogs/test\\10250.jpg',
#  'data/cat_and_dogs/test\\10251.jpg',
#  'data/cat_and_dogs/test\\10252.jpg',
#  'data/cat_and_dogs/test\\10253.jpg',
#  'data/cat_and_dogs/test\\10254.jpg',
#  'data/cat_and_dogs/test\\10255.jpg',
#  'data/cat_and_dogs/test\\10256.jpg',
#  'data/cat_and_dogs/test\\10257.jpg',
#  'data/cat_and_dogs/test\\10258.jpg',
#  'data/cat_and_dogs/test\\10259.jpg',
#  'data/cat_and_dogs/test\\1026.jpg',
#  'data/cat_and_dogs/test\\10260.jpg',
#  'data/cat_and_dogs/test\\10261.jpg',
#  'data/cat_and_dogs/test\\10262.jpg',
#  'data/cat_and_dogs/test\\10263.jpg',
#  'data/cat_and_dogs/test\\10264.jpg',
#  'data/cat_and_dogs/test\\10265.jpg',
#  'data/cat_and_dogs/test\\10266.jpg',
#  'data/cat_and_dogs/test\\10267.jpg',
#  'data/cat_and_dogs/test\\10268.jpg',
#  'data/cat_and_dogs/test\\10269.jpg',
#  'data/cat_and_dogs/test\\1027.jpg',
#  'data/cat_and_dogs/test\\10270.jpg',
#  'data/cat_and_dogs/test\\10271.jpg',
#  'data/cat_and_dogs/test\\10272.jpg',
#  'data/cat_and_dogs/test\\10273.jpg',
#  'data/cat_and_dogs/test\\10274.jpg',
#  'data/cat_and_dogs/test\\10275.jpg',
#  'data/cat_and_dogs/test\\10276.jpg',
#  'data/cat_and_dogs/test\\10277.jpg',
#  'data/cat_and_dogs/test\\10278.jpg',
#  'data/cat_and_dogs/test\\10279.jpg',
#  'data/cat_and_dogs/test\\1028.jpg',
#  'data/cat_and_dogs/test\\10280.jpg',
#  'data/cat_and_dogs/test\\10281.jpg',
#  'data/cat_and_dogs/test\\10282.jpg',
#  'data/cat_and_dogs/test\\10283.jpg',
#  'data/cat_and_dogs/test\\10284.jpg',
#  'data/cat_and_dogs/test\\10285.jpg',
#  'data/cat_and_dogs/test\\10286.jpg',
#  'data/cat_and_dogs/test\\10287.jpg',
#  'data/cat_and_dogs/test\\10288.jpg',
#  'data/cat_and_dogs/test\\10289.jpg',
#  'data/cat_and_dogs/test\\1029.jpg',
#  'data/cat_and_dogs/test\\10290.jpg',
#  'data/cat_and_dogs/test\\10291.jpg',
#  'data/cat_and_dogs/test\\10292.jpg',
#  'data/cat_and_dogs/test\\10293.jpg',
#  'data/cat_and_dogs/test\\10294.jpg',
#  'data/cat_and_dogs/test\\10295.jpg',
#  'data/cat_and_dogs/test\\10296.jpg',
#  'data/cat_and_dogs/test\\10297.jpg',
#  'data/cat_and_dogs/test\\10298.jpg',
#  'data/cat_and_dogs/test\\10299.jpg',
#  'data/cat_and_dogs/test\\103.jpg',
#  'data/cat_and_dogs/test\\1030.jpg',
#  'data/cat_and_dogs/test\\10300.jpg',
#  'data/cat_and_dogs/test\\10301.jpg',
#  'data/cat_and_dogs/test\\10302.jpg',
#  'data/cat_and_dogs/test\\10303.jpg',
#  'data/cat_and_dogs/test\\10304.jpg',
#  'data/cat_and_dogs/test\\10305.jpg',
#  'data/cat_and_dogs/test\\10306.jpg',
#  'data/cat_and_dogs/test\\10307.jpg',
#  'data/cat_and_dogs/test\\10308.jpg',
#  'data/cat_and_dogs/test\\10309.jpg',
#  'data/cat_and_dogs/test\\1031.jpg',
#  'data/cat_and_dogs/test\\10310.jpg',
#  'data/cat_and_dogs/test\\10311.jpg',
#  'data/cat_and_dogs/test\\10312.jpg',
#  'data/cat_and_dogs/test\\10313.jpg',
#  'data/cat_and_dogs/test\\10314.jpg',
#  'data/cat_and_dogs/test\\10315.jpg',
#  'data/cat_and_dogs/test\\10316.jpg',
#  'data/cat_and_dogs/test\\10317.jpg',
#  'data/cat_and_dogs/test\\10318.jpg',
#  'data/cat_and_dogs/test\\10319.jpg',
#  'data/cat_and_dogs/test\\1032.jpg',
#  'data/cat_and_dogs/test\\10320.jpg',
#  'data/cat_and_dogs/test\\10321.jpg',
#  'data/cat_and_dogs/test\\10322.jpg',
#  'data/cat_and_dogs/test\\10323.jpg',
#  'data/cat_and_dogs/test\\10324.jpg',
#  'data/cat_and_dogs/test\\10325.jpg',
#  'data/cat_and_dogs/test\\10326.jpg',
#  'data/cat_and_dogs/test\\10327.jpg',
#  'data/cat_and_dogs/test\\10328.jpg',
#  'data/cat_and_dogs/test\\10329.jpg',
#  'data/cat_and_dogs/test\\1033.jpg',
#  'data/cat_and_dogs/test\\10330.jpg',
#  'data/cat_and_dogs/test\\10331.jpg',
#  'data/cat_and_dogs/test\\10332.jpg',
#  'data/cat_and_dogs/test\\10333.jpg',
#  'data/cat_and_dogs/test\\10334.jpg',
#  'data/cat_and_dogs/test\\10335.jpg',
#  'data/cat_and_dogs/test\\10336.jpg',
#  'data/cat_and_dogs/test\\10337.jpg',
#  'data/cat_and_dogs/test\\10338.jpg',
#  'data/cat_and_dogs/test\\10339.jpg',
#  'data/cat_and_dogs/test\\1034.jpg',
#  'data/cat_and_dogs/test\\10340.jpg',
#  'data/cat_and_dogs/test\\10341.jpg',
#  'data/cat_and_dogs/test\\10342.jpg',
#  'data/cat_and_dogs/test\\10343.jpg',
#  'data/cat_and_dogs/test\\10344.jpg',
#  'data/cat_and_dogs/test\\10345.jpg',
#  'data/cat_and_dogs/test\\10346.jpg',
#  'data/cat_and_dogs/test\\10347.jpg',
#  'data/cat_and_dogs/test\\10348.jpg',
#  'data/cat_and_dogs/test\\10349.jpg',
#  'data/cat_and_dogs/test\\1035.jpg',
#  'data/cat_and_dogs/test\\10350.jpg',
#  'data/cat_and_dogs/test\\10351.jpg',
#  'data/cat_and_dogs/test\\10352.jpg',
#  'data/cat_and_dogs/test\\10353.jpg',
#  'data/cat_and_dogs/test\\10354.jpg',
#  'data/cat_and_dogs/test\\10355.jpg',
#  'data/cat_and_dogs/test\\10356.jpg',
#  'data/cat_and_dogs/test\\10357.jpg',
#  'data/cat_and_dogs/test\\10358.jpg',
#  'data/cat_and_dogs/test\\10359.jpg',
#  'data/cat_and_dogs/test\\1036.jpg',
#  'data/cat_and_dogs/test\\10360.jpg',
#  'data/cat_and_dogs/test\\10361.jpg',
#  'data/cat_and_dogs/test\\10362.jpg',
#  'data/cat_and_dogs/test\\10363.jpg',
#  'data/cat_and_dogs/test\\10364.jpg',
#  'data/cat_and_dogs/test\\10365.jpg',
#  'data/cat_and_dogs/test\\10366.jpg',
#  'data/cat_and_dogs/test\\10367.jpg',
#  'data/cat_and_dogs/test\\10368.jpg',
#  'data/cat_and_dogs/test\\10369.jpg',
#  'data/cat_and_dogs/test\\1037.jpg',
#  'data/cat_and_dogs/test\\10370.jpg',
#  'data/cat_and_dogs/test\\10371.jpg',
#  'data/cat_and_dogs/test\\10372.jpg',
#  'data/cat_and_dogs/test\\10373.jpg',
#  'data/cat_and_dogs/test\\10374.jpg',
#  'data/cat_and_dogs/test\\10375.jpg',
#  'data/cat_and_dogs/test\\10376.jpg',
#  'data/cat_and_dogs/test\\10377.jpg',
#  'data/cat_and_dogs/test\\10378.jpg',
#  'data/cat_and_dogs/test\\10379.jpg',
#  'data/cat_and_dogs/test\\1038.jpg',
#  'data/cat_and_dogs/test\\10380.jpg',
#  'data/cat_and_dogs/test\\10381.jpg',
#  'data/cat_and_dogs/test\\10382.jpg',
#  'data/cat_and_dogs/test\\10383.jpg',
#  'data/cat_and_dogs/test\\10384.jpg',
#  'data/cat_and_dogs/test\\10385.jpg',
#  'data/cat_and_dogs/test\\10386.jpg',
#  'data/cat_and_dogs/test\\10387.jpg',
#  'data/cat_and_dogs/test\\10388.jpg',
#  'data/cat_and_dogs/test\\10389.jpg',
#  'data/cat_and_dogs/test\\1039.jpg',
#  'data/cat_and_dogs/test\\10390.jpg',
#  'data/cat_and_dogs/test\\10391.jpg',
#  'data/cat_and_dogs/test\\10392.jpg',
#  'data/cat_and_dogs/test\\10393.jpg',
#  'data/cat_and_dogs/test\\10394.jpg',
#  'data/cat_and_dogs/test\\10395.jpg',
#  'data/cat_and_dogs/test\\10396.jpg',
#  'data/cat_and_dogs/test\\10397.jpg',
#  'data/cat_and_dogs/test\\10398.jpg',
#  'data/cat_and_dogs/test\\10399.jpg',
#  'data/cat_and_dogs/test\\104.jpg',
#  'data/cat_and_dogs/test\\1040.jpg',
#  'data/cat_and_dogs/test\\10400.jpg',
#  'data/cat_and_dogs/test\\10401.jpg',
#  'data/cat_and_dogs/test\\10402.jpg',
#  'data/cat_and_dogs/test\\10403.jpg',
#  'data/cat_and_dogs/test\\10404.jpg',
#  'data/cat_and_dogs/test\\10405.jpg',
#  'data/cat_and_dogs/test\\10406.jpg',
#  'data/cat_and_dogs/test\\10407.jpg',
#  'data/cat_and_dogs/test\\10408.jpg',
#  'data/cat_and_dogs/test\\10409.jpg',
#  'data/cat_and_dogs/test\\1041.jpg',
#  'data/cat_and_dogs/test\\10410.jpg',
#  'data/cat_and_dogs/test\\10411.jpg',
#  'data/cat_and_dogs/test\\10412.jpg',
#  'data/cat_and_dogs/test\\10413.jpg',
#  'data/cat_and_dogs/test\\10414.jpg',
#  'data/cat_and_dogs/test\\10415.jpg',
#  'data/cat_and_dogs/test\\10416.jpg',
#  'data/cat_and_dogs/test\\10417.jpg',
#  'data/cat_and_dogs/test\\10418.jpg',
#  'data/cat_and_dogs/test\\10419.jpg',
#  'data/cat_and_dogs/test\\1042.jpg',
#  'data/cat_and_dogs/test\\10420.jpg',
#  'data/cat_and_dogs/test\\10421.jpg',
#  'data/cat_and_dogs/test\\10422.jpg',
#  'data/cat_and_dogs/test\\10423.jpg',
#  'data/cat_and_dogs/test\\10424.jpg',
#  'data/cat_and_dogs/test\\10425.jpg',
#  'data/cat_and_dogs/test\\10426.jpg',
#  'data/cat_and_dogs/test\\10427.jpg',
#  'data/cat_and_dogs/test\\10428.jpg',
#  'data/cat_and_dogs/test\\10429.jpg',
#  'data/cat_and_dogs/test\\1043.jpg',
#  'data/cat_and_dogs/test\\10430.jpg',
#  'data/cat_and_dogs/test\\10431.jpg',
#  'data/cat_and_dogs/test\\10432.jpg',
#  'data/cat_and_dogs/test\\10433.jpg',
#  'data/cat_and_dogs/test\\10434.jpg',
#  'data/cat_and_dogs/test\\10435.jpg',
#  'data/cat_and_dogs/test\\10436.jpg',
#  'data/cat_and_dogs/test\\10437.jpg',
#  'data/cat_and_dogs/test\\10438.jpg',
#  'data/cat_and_dogs/test\\10439.jpg',
#  'data/cat_and_dogs/test\\1044.jpg',
#  'data/cat_and_dogs/test\\10440.jpg',
#  'data/cat_and_dogs/test\\10441.jpg',
#  'data/cat_and_dogs/test\\10442.jpg',
#  'data/cat_and_dogs/test\\10443.jpg',
#  'data/cat_and_dogs/test\\10444.jpg',
#  'data/cat_and_dogs/test\\10445.jpg',
#  'data/cat_and_dogs/test\\10446.jpg',
#  'data/cat_and_dogs/test\\10447.jpg',
#  'data/cat_and_dogs/test\\10448.jpg',
#  'data/cat_and_dogs/test\\10449.jpg',
#  'data/cat_and_dogs/test\\1045.jpg',
#  'data/cat_and_dogs/test\\10450.jpg',
#  'data/cat_and_dogs/test\\10451.jpg',
#  'data/cat_and_dogs/test\\10452.jpg',
#  'data/cat_and_dogs/test\\10453.jpg',
#  'data/cat_and_dogs/test\\10454.jpg',
#  'data/cat_and_dogs/test\\10455.jpg',
#  'data/cat_and_dogs/test\\10456.jpg',
#  'data/cat_and_dogs/test\\10457.jpg',
#  'data/cat_and_dogs/test\\10458.jpg',
#  'data/cat_and_dogs/test\\10459.jpg',
#  'data/cat_and_dogs/test\\1046.jpg',
#  'data/cat_and_dogs/test\\10460.jpg',
#  'data/cat_and_dogs/test\\10461.jpg',
#  'data/cat_and_dogs/test\\10462.jpg',
#  'data/cat_and_dogs/test\\10463.jpg',
#  'data/cat_and_dogs/test\\10464.jpg',
#  'data/cat_and_dogs/test\\10465.jpg',
#  'data/cat_and_dogs/test\\10466.jpg',
#  'data/cat_and_dogs/test\\10467.jpg',
#  'data/cat_and_dogs/test\\10468.jpg',
#  'data/cat_and_dogs/test\\10469.jpg',
#  'data/cat_and_dogs/test\\1047.jpg',
#  'data/cat_and_dogs/test\\10470.jpg',
#  'data/cat_and_dogs/test\\10471.jpg',
#  'data/cat_and_dogs/test\\10472.jpg',
#  'data/cat_and_dogs/test\\10473.jpg',
#  'data/cat_and_dogs/test\\10474.jpg',
#  'data/cat_and_dogs/test\\10475.jpg',
#  'data/cat_and_dogs/test\\10476.jpg',
#  'data/cat_and_dogs/test\\10477.jpg',
#  'data/cat_and_dogs/test\\10478.jpg',
#  'data/cat_and_dogs/test\\10479.jpg',
#  'data/cat_and_dogs/test\\1048.jpg',
#  'data/cat_and_dogs/test\\10480.jpg',
#  'data/cat_and_dogs/test\\10481.jpg',
#  'data/cat_and_dogs/test\\10482.jpg',
#  'data/cat_and_dogs/test\\10483.jpg',
#  'data/cat_and_dogs/test\\10484.jpg',
#  'data/cat_and_dogs/test\\10485.jpg',
#  'data/cat_and_dogs/test\\10486.jpg',
#  'data/cat_and_dogs/test\\10487.jpg',
#  'data/cat_and_dogs/test\\10488.jpg',
#  'data/cat_and_dogs/test\\10489.jpg',
#  'data/cat_and_dogs/test\\1049.jpg',
#  'data/cat_and_dogs/test\\10490.jpg',
#  'data/cat_and_dogs/test\\10491.jpg',
#  'data/cat_and_dogs/test\\10492.jpg',
#  'data/cat_and_dogs/test\\10493.jpg',
#  'data/cat_and_dogs/test\\10494.jpg',
#  'data/cat_and_dogs/test\\10495.jpg',
#  'data/cat_and_dogs/test\\10496.jpg',
#  'data/cat_and_dogs/test\\10497.jpg',
#  'data/cat_and_dogs/test\\10498.jpg',
#  'data/cat_and_dogs/test\\10499.jpg',
#  'data/cat_and_dogs/test\\105.jpg',
#  'data/cat_and_dogs/test\\1050.jpg',
#  'data/cat_and_dogs/test\\10500.jpg',
#  'data/cat_and_dogs/test\\10501.jpg',
#  'data/cat_and_dogs/test\\10502.jpg',
#  'data/cat_and_dogs/test\\10503.jpg',
#  'data/cat_and_dogs/test\\10504.jpg',
#  'data/cat_and_dogs/test\\10505.jpg',
#  'data/cat_and_dogs/test\\10506.jpg',
#  'data/cat_and_dogs/test\\10507.jpg',
#  'data/cat_and_dogs/test\\10508.jpg',
#  'data/cat_and_dogs/test\\10509.jpg',
#  'data/cat_and_dogs/test\\1051.jpg',
#  'data/cat_and_dogs/test\\10510.jpg',
#  'data/cat_and_dogs/test\\10511.jpg',
#  'data/cat_and_dogs/test\\10512.jpg',
#  'data/cat_and_dogs/test\\10513.jpg',
#  'data/cat_and_dogs/test\\10514.jpg',
#  'data/cat_and_dogs/test\\10515.jpg',
#  'data/cat_and_dogs/test\\10516.jpg',
#  'data/cat_and_dogs/test\\10517.jpg',
#  'data/cat_and_dogs/test\\10518.jpg',
#  'data/cat_and_dogs/test\\10519.jpg',
#  'data/cat_and_dogs/test\\1052.jpg',
#  'data/cat_and_dogs/test\\10520.jpg',
#  'data/cat_and_dogs/test\\10521.jpg',
#  'data/cat_and_dogs/test\\10522.jpg',
#  'data/cat_and_dogs/test\\10523.jpg',
#  'data/cat_and_dogs/test\\10524.jpg',
#  'data/cat_and_dogs/test\\10525.jpg',
#  'data/cat_and_dogs/test\\10526.jpg',
#  'data/cat_and_dogs/test\\10527.jpg',
#  'data/cat_and_dogs/test\\10528.jpg',
#  'data/cat_and_dogs/test\\10529.jpg',
#  'data/cat_and_dogs/test\\1053.jpg',
#  'data/cat_and_dogs/test\\10530.jpg',
#  'data/cat_and_dogs/test\\10531.jpg',
#  'data/cat_and_dogs/test\\10532.jpg',
#  'data/cat_and_dogs/test\\10533.jpg',
#  'data/cat_and_dogs/test\\10534.jpg',
#  'data/cat_and_dogs/test\\10535.jpg',
#  'data/cat_and_dogs/test\\10536.jpg',
#  'data/cat_and_dogs/test\\10537.jpg',
#  'data/cat_and_dogs/test\\10538.jpg',
#  'data/cat_and_dogs/test\\10539.jpg',
#  'data/cat_and_dogs/test\\1054.jpg',
#  'data/cat_and_dogs/test\\10540.jpg',
#  'data/cat_and_dogs/test\\10541.jpg',
#  'data/cat_and_dogs/test\\10542.jpg',
#  'data/cat_and_dogs/test\\10543.jpg',
#  'data/cat_and_dogs/test\\10544.jpg',
#  'data/cat_and_dogs/test\\10545.jpg',
#  'data/cat_and_dogs/test\\10546.jpg',
#  'data/cat_and_dogs/test\\10547.jpg',
#  'data/cat_and_dogs/test\\10548.jpg',
#  'data/cat_and_dogs/test\\10549.jpg',
#  'data/cat_and_dogs/test\\1055.jpg',
#  'data/cat_and_dogs/test\\10550.jpg',
#  'data/cat_and_dogs/test\\10551.jpg',
#  'data/cat_and_dogs/test\\10552.jpg',
#  'data/cat_and_dogs/test\\10553.jpg',
#  'data/cat_and_dogs/test\\10554.jpg',
#  'data/cat_and_dogs/test\\10555.jpg',
#  'data/cat_and_dogs/test\\10556.jpg',
#  'data/cat_and_dogs/test\\10557.jpg',
#  'data/cat_and_dogs/test\\10558.jpg',
#  'data/cat_and_dogs/test\\10559.jpg',
#  'data/cat_and_dogs/test\\1056.jpg',
#  'data/cat_and_dogs/test\\10560.jpg',
#  'data/cat_and_dogs/test\\10561.jpg',
#  'data/cat_and_dogs/test\\10562.jpg',
#  'data/cat_and_dogs/test\\10563.jpg',
#  'data/cat_and_dogs/test\\10564.jpg',
#  'data/cat_and_dogs/test\\10565.jpg',
#  'data/cat_and_dogs/test\\10566.jpg',
#  'data/cat_and_dogs/test\\10567.jpg',
#  'data/cat_and_dogs/test\\10568.jpg',
#  'data/cat_and_dogs/test\\10569.jpg',
#  'data/cat_and_dogs/test\\1057.jpg',
#  'data/cat_and_dogs/test\\10570.jpg',
#  'data/cat_and_dogs/test\\10571.jpg',
#  'data/cat_and_dogs/test\\10572.jpg',
#  'data/cat_and_dogs/test\\10573.jpg',
#  'data/cat_and_dogs/test\\10574.jpg',
#  'data/cat_and_dogs/test\\10575.jpg',
#  'data/cat_and_dogs/test\\10576.jpg',
#  'data/cat_and_dogs/test\\10577.jpg',
#  'data/cat_and_dogs/test\\10578.jpg',
#  'data/cat_and_dogs/test\\10579.jpg',
#  'data/cat_and_dogs/test\\1058.jpg',
#  'data/cat_and_dogs/test\\10580.jpg',
#  'data/cat_and_dogs/test\\10581.jpg',
#  'data/cat_and_dogs/test\\10582.jpg',
#  'data/cat_and_dogs/test\\10583.jpg',
#  'data/cat_and_dogs/test\\10584.jpg',
#  'data/cat_and_dogs/test\\10585.jpg',
#  'data/cat_and_dogs/test\\10586.jpg',
#  'data/cat_and_dogs/test\\10587.jpg',
#  'data/cat_and_dogs/test\\10588.jpg',
#  'data/cat_and_dogs/test\\10589.jpg',
#  'data/cat_and_dogs/test\\1059.jpg',
#  'data/cat_and_dogs/test\\10590.jpg',
#  'data/cat_and_dogs/test\\10591.jpg',
#  'data/cat_and_dogs/test\\10592.jpg',
#  'data/cat_and_dogs/test\\10593.jpg',
#  'data/cat_and_dogs/test\\10594.jpg',
#  'data/cat_and_dogs/test\\10595.jpg',
#  'data/cat_and_dogs/test\\10596.jpg',
#  'data/cat_and_dogs/test\\10597.jpg',
#  'data/cat_and_dogs/test\\10598.jpg',
#  'data/cat_and_dogs/test\\10599.jpg',
#  'data/cat_and_dogs/test\\106.jpg',
#  'data/cat_and_dogs/test\\1060.jpg',
#  'data/cat_and_dogs/test\\10600.jpg',
#  'data/cat_and_dogs/test\\10601.jpg',
#  'data/cat_and_dogs/test\\10602.jpg',
#  'data/cat_and_dogs/test\\10603.jpg',
#  'data/cat_and_dogs/test\\10604.jpg',
#  'data/cat_and_dogs/test\\10605.jpg',
#  'data/cat_and_dogs/test\\10606.jpg',
#  'data/cat_and_dogs/test\\10607.jpg',
#  'data/cat_and_dogs/test\\10608.jpg',
#  'data/cat_and_dogs/test\\10609.jpg',
#  'data/cat_and_dogs/test\\1061.jpg',
#  'data/cat_and_dogs/test\\10610.jpg',
#  'data/cat_and_dogs/test\\10611.jpg',
#  'data/cat_and_dogs/test\\10612.jpg',
#  'data/cat_and_dogs/test\\10613.jpg',
#  'data/cat_and_dogs/test\\10614.jpg',
#  'data/cat_and_dogs/test\\10615.jpg',
#  'data/cat_and_dogs/test\\10616.jpg',
#  'data/cat_and_dogs/test\\10617.jpg',
#  'data/cat_and_dogs/test\\10618.jpg',
#  'data/cat_and_dogs/test\\10619.jpg',
#  'data/cat_and_dogs/test\\1062.jpg',
#  'data/cat_and_dogs/test\\10620.jpg',
#  'data/cat_and_dogs/test\\10621.jpg',
#  'data/cat_and_dogs/test\\10622.jpg',
#  'data/cat_and_dogs/test\\10623.jpg',
#  'data/cat_and_dogs/test\\10624.jpg',
#  'data/cat_and_dogs/test\\10625.jpg',
#  'data/cat_and_dogs/test\\10626.jpg',
#  'data/cat_and_dogs/test\\10627.jpg',
#  'data/cat_and_dogs/test\\10628.jpg',
#  'data/cat_and_dogs/test\\10629.jpg',
#  'data/cat_and_dogs/test\\1063.jpg',
#  'data/cat_and_dogs/test\\10630.jpg',
#  'data/cat_and_dogs/test\\10631.jpg',
#  'data/cat_and_dogs/test\\10632.jpg',
#  'data/cat_and_dogs/test\\10633.jpg',
#  'data/cat_and_dogs/test\\10634.jpg',
#  'data/cat_and_dogs/test\\10635.jpg',
#  'data/cat_and_dogs/test\\10636.jpg',
#  'data/cat_and_dogs/test\\10637.jpg',
#  'data/cat_and_dogs/test\\10638.jpg',
#  'data/cat_and_dogs/test\\10639.jpg',
#  'data/cat_and_dogs/test\\1064.jpg',
#  'data/cat_and_dogs/test\\10640.jpg',
#  'data/cat_and_dogs/test\\10641.jpg',
#  'data/cat_and_dogs/test\\10642.jpg',
#  'data/cat_and_dogs/test\\10643.jpg',
#  'data/cat_and_dogs/test\\10644.jpg',
#  'data/cat_and_dogs/test\\10645.jpg',
#  'data/cat_and_dogs/test\\10646.jpg',
#  'data/cat_and_dogs/test\\10647.jpg',
#  'data/cat_and_dogs/test\\10648.jpg',
#  'data/cat_and_dogs/test\\10649.jpg',
#  'data/cat_and_dogs/test\\1065.jpg',
#  'data/cat_and_dogs/test\\10650.jpg',
#  'data/cat_and_dogs/test\\10651.jpg',
#  'data/cat_and_dogs/test\\10652.jpg',
#  'data/cat_and_dogs/test\\10653.jpg',
#  'data/cat_and_dogs/test\\10654.jpg',
#  'data/cat_and_dogs/test\\10655.jpg',
#  'data/cat_and_dogs/test\\10656.jpg',
#  'data/cat_and_dogs/test\\10657.jpg',
#  'data/cat_and_dogs/test\\10658.jpg',
#  'data/cat_and_dogs/test\\10659.jpg',
#  'data/cat_and_dogs/test\\1066.jpg',
#  'data/cat_and_dogs/test\\10660.jpg',
#  'data/cat_and_dogs/test\\10661.jpg',
#  'data/cat_and_dogs/test\\10662.jpg',
#  'data/cat_and_dogs/test\\10663.jpg',
#  'data/cat_and_dogs/test\\10664.jpg',
#  'data/cat_and_dogs/test\\10665.jpg',
#  'data/cat_and_dogs/test\\10666.jpg',
#  'data/cat_and_dogs/test\\10667.jpg',
#  'data/cat_and_dogs/test\\10668.jpg',
#  'data/cat_and_dogs/test\\10669.jpg',
#  'data/cat_and_dogs/test\\1067.jpg',
#  'data/cat_and_dogs/test\\10670.jpg',
#  'data/cat_and_dogs/test\\10671.jpg',
#  'data/cat_and_dogs/test\\10672.jpg',
#  'data/cat_and_dogs/test\\10673.jpg',
#  'data/cat_and_dogs/test\\10674.jpg',
#  'data/cat_and_dogs/test\\10675.jpg',
#  'data/cat_and_dogs/test\\10676.jpg',
#  'data/cat_and_dogs/test\\10677.jpg',
#  'data/cat_and_dogs/test\\10678.jpg',
#  'data/cat_and_dogs/test\\10679.jpg',
#  'data/cat_and_dogs/test\\1068.jpg',
#  'data/cat_and_dogs/test\\10680.jpg',
#  'data/cat_and_dogs/test\\10681.jpg',
#  'data/cat_and_dogs/test\\10682.jpg',
#  'data/cat_and_dogs/test\\10683.jpg',
#  'data/cat_and_dogs/test\\10684.jpg',
#  'data/cat_and_dogs/test\\10685.jpg',
#  'data/cat_and_dogs/test\\10686.jpg',
#  'data/cat_and_dogs/test\\10687.jpg',
#  'data/cat_and_dogs/test\\10688.jpg',
#  'data/cat_and_dogs/test\\10689.jpg',
#  'data/cat_and_dogs/test\\1069.jpg',
#  'data/cat_and_dogs/test\\10690.jpg',
#  'data/cat_and_dogs/test\\10691.jpg',
#  'data/cat_and_dogs/test\\10692.jpg',
#  'data/cat_and_dogs/test\\10693.jpg',
#  'data/cat_and_dogs/test\\10694.jpg',
#  'data/cat_and_dogs/test\\10695.jpg',
#  'data/cat_and_dogs/test\\10696.jpg',
#  'data/cat_and_dogs/test\\10697.jpg',
#  'data/cat_and_dogs/test\\10698.jpg',
#  'data/cat_and_dogs/test\\10699.jpg',
#  'data/cat_and_dogs/test\\107.jpg',
#  'data/cat_and_dogs/test\\1070.jpg',
#  'data/cat_and_dogs/test\\10700.jpg',
#  'data/cat_and_dogs/test\\10701.jpg',
#  'data/cat_and_dogs/test\\10702.jpg',
#  'data/cat_and_dogs/test\\10703.jpg',
#  'data/cat_and_dogs/test\\10704.jpg',
#  'data/cat_and_dogs/test\\10705.jpg',
#  'data/cat_and_dogs/test\\10706.jpg',
#  'data/cat_and_dogs/test\\10707.jpg',
#  'data/cat_and_dogs/test\\10708.jpg',
#  'data/cat_and_dogs/test\\10709.jpg',
#  'data/cat_and_dogs/test\\1071.jpg',
#  'data/cat_and_dogs/test\\10710.jpg',
#  'data/cat_and_dogs/test\\10711.jpg',
#  'data/cat_and_dogs/test\\10712.jpg',
#  'data/cat_and_dogs/test\\10713.jpg',
#  'data/cat_and_dogs/test\\10714.jpg',
#  'data/cat_and_dogs/test\\10715.jpg',
#  'data/cat_and_dogs/test\\10716.jpg',
#  'data/cat_and_dogs/test\\10717.jpg',
#  'data/cat_and_dogs/test\\10718.jpg',
#  'data/cat_and_dogs/test\\10719.jpg',
#  'data/cat_and_dogs/test\\1072.jpg',
#  'data/cat_and_dogs/test\\10720.jpg',
#  'data/cat_and_dogs/test\\10721.jpg',
#  'data/cat_and_dogs/test\\10722.jpg',
#  'data/cat_and_dogs/test\\10723.jpg',
#  'data/cat_and_dogs/test\\10724.jpg',
#  'data/cat_and_dogs/test\\10725.jpg',
#  'data/cat_and_dogs/test\\10726.jpg',
#  'data/cat_and_dogs/test\\10727.jpg',
#  'data/cat_and_dogs/test\\10728.jpg',
#  'data/cat_and_dogs/test\\10729.jpg',
#  'data/cat_and_dogs/test\\1073.jpg',
#  'data/cat_and_dogs/test\\10730.jpg',
#  'data/cat_and_dogs/test\\10731.jpg',
#  'data/cat_and_dogs/test\\10732.jpg',
#  'data/cat_and_dogs/test\\10733.jpg',
#  'data/cat_and_dogs/test\\10734.jpg',
#  'data/cat_and_dogs/test\\10735.jpg',
#  'data/cat_and_dogs/test\\10736.jpg',
#  'data/cat_and_dogs/test\\10737.jpg',
#  'data/cat_and_dogs/test\\10738.jpg',
#  'data/cat_and_dogs/test\\10739.jpg',
#  'data/cat_and_dogs/test\\1074.jpg',
#  'data/cat_and_dogs/test\\10740.jpg',
#  'data/cat_and_dogs/test\\10741.jpg',
#  'data/cat_and_dogs/test\\10742.jpg',
#  'data/cat_and_dogs/test\\10743.jpg',
#  'data/cat_and_dogs/test\\10744.jpg',
#  'data/cat_and_dogs/test\\10745.jpg',
#  'data/cat_and_dogs/test\\10746.jpg',
#  'data/cat_and_dogs/test\\10747.jpg',
#  'data/cat_and_dogs/test\\10748.jpg',
#  'data/cat_and_dogs/test\\10749.jpg',
#  'data/cat_and_dogs/test\\1075.jpg',
#  'data/cat_and_dogs/test\\10750.jpg',
#  'data/cat_and_dogs/test\\10751.jpg',
#  'data/cat_and_dogs/test\\10752.jpg',
#  'data/cat_and_dogs/test\\10753.jpg',
#  'data/cat_and_dogs/test\\10754.jpg',
#  'data/cat_and_dogs/test\\10755.jpg',
#  'data/cat_and_dogs/test\\10756.jpg',
#  'data/cat_and_dogs/test\\10757.jpg',
#  'data/cat_and_dogs/test\\10758.jpg',
#  'data/cat_and_dogs/test\\10759.jpg',
#  'data/cat_and_dogs/test\\1076.jpg',
#  'data/cat_and_dogs/test\\10760.jpg',
#  'data/cat_and_dogs/test\\10761.jpg',
#  'data/cat_and_dogs/test\\10762.jpg',
#  'data/cat_and_dogs/test\\10763.jpg',
#  'data/cat_and_dogs/test\\10764.jpg',
#  'data/cat_and_dogs/test\\10765.jpg',
#  'data/cat_and_dogs/test\\10766.jpg',
#  'data/cat_and_dogs/test\\10767.jpg',
#  'data/cat_and_dogs/test\\10768.jpg',
#  'data/cat_and_dogs/test\\10769.jpg',
#  'data/cat_and_dogs/test\\1077.jpg',
#  'data/cat_and_dogs/test\\10770.jpg',
#  'data/cat_and_dogs/test\\10771.jpg',
#  'data/cat_and_dogs/test\\10772.jpg',
#  'data/cat_and_dogs/test\\10773.jpg',
#  'data/cat_and_dogs/test\\10774.jpg',
#  'data/cat_and_dogs/test\\10775.jpg',
#  'data/cat_and_dogs/test\\10776.jpg',
#  'data/cat_and_dogs/test\\10777.jpg',
#  'data/cat_and_dogs/test\\10778.jpg',
#  'data/cat_and_dogs/test\\10779.jpg',
#  'data/cat_and_dogs/test\\1078.jpg',
#  'data/cat_and_dogs/test\\10780.jpg',
#  'data/cat_and_dogs/test\\10781.jpg',
#  'data/cat_and_dogs/test\\10782.jpg',
#  'data/cat_and_dogs/test\\10783.jpg',
#  'data/cat_and_dogs/test\\10784.jpg',
#  'data/cat_and_dogs/test\\10785.jpg',
#  'data/cat_and_dogs/test\\10786.jpg',
#  'data/cat_and_dogs/test\\10787.jpg',
#  'data/cat_and_dogs/test\\10788.jpg',
#  'data/cat_and_dogs/test\\10789.jpg',
#  'data/cat_and_dogs/test\\1079.jpg',
#  'data/cat_and_dogs/test\\10790.jpg',
#  'data/cat_and_dogs/test\\10791.jpg',
#  'data/cat_and_dogs/test\\10792.jpg',
#  'data/cat_and_dogs/test\\10793.jpg',
#  'data/cat_and_dogs/test\\10794.jpg',
#  'data/cat_and_dogs/test\\10795.jpg',
#  'data/cat_and_dogs/test\\10796.jpg',
#  'data/cat_and_dogs/test\\10797.jpg',
#  'data/cat_and_dogs/test\\10798.jpg',
#  'data/cat_and_dogs/test\\10799.jpg',
#  'data/cat_and_dogs/test\\108.jpg',
#  'data/cat_and_dogs/test\\1080.jpg',
#  'data/cat_and_dogs/test\\10800.jpg',
#  'data/cat_and_dogs/test\\10801.jpg',
#  'data/cat_and_dogs/test\\10802.jpg',
#  'data/cat_and_dogs/test\\10803.jpg',
#  'data/cat_and_dogs/test\\10804.jpg',
#  'data/cat_and_dogs/test\\10805.jpg',
#  'data/cat_and_dogs/test\\10806.jpg',
#  'data/cat_and_dogs/test\\10807.jpg',
#  'data/cat_and_dogs/test\\10808.jpg',
#  'data/cat_and_dogs/test\\10809.jpg',
#  'data/cat_and_dogs/test\\1081.jpg',
#  'data/cat_and_dogs/test\\10810.jpg',
#  'data/cat_and_dogs/test\\10811.jpg',
#  'data/cat_and_dogs/test\\10812.jpg',
#  'data/cat_and_dogs/test\\10813.jpg',
#  'data/cat_and_dogs/test\\10814.jpg',
#  'data/cat_and_dogs/test\\10815.jpg',
#  'data/cat_and_dogs/test\\10816.jpg',
#  'data/cat_and_dogs/test\\10817.jpg',
#  'data/cat_and_dogs/test\\10818.jpg',
#  'data/cat_and_dogs/test\\10819.jpg',
#  'data/cat_and_dogs/test\\1082.jpg',
#  'data/cat_and_dogs/test\\10820.jpg',
#  'data/cat_and_dogs/test\\10821.jpg',
#  'data/cat_and_dogs/test\\10822.jpg',
#  'data/cat_and_dogs/test\\10823.jpg',
#  'data/cat_and_dogs/test\\10824.jpg',
#  'data/cat_and_dogs/test\\10825.jpg',
#  'data/cat_and_dogs/test\\10826.jpg',
#  'data/cat_and_dogs/test\\10827.jpg',
#  'data/cat_and_dogs/test\\10828.jpg',
#  'data/cat_and_dogs/test\\10829.jpg',
#  'data/cat_and_dogs/test\\1083.jpg',
#  'data/cat_and_dogs/test\\10830.jpg',
#  'data/cat_and_dogs/test\\10831.jpg',
#  'data/cat_and_dogs/test\\10832.jpg',
#  'data/cat_and_dogs/test\\10833.jpg',
#  'data/cat_and_dogs/test\\10834.jpg',
#  'data/cat_and_dogs/test\\10835.jpg',
#  'data/cat_and_dogs/test\\10836.jpg',
#  'data/cat_and_dogs/test\\10837.jpg',
#  'data/cat_and_dogs/test\\10838.jpg',
#  'data/cat_and_dogs/test\\10839.jpg',
#  'data/cat_and_dogs/test\\1084.jpg',
#  'data/cat_and_dogs/test\\10840.jpg',
#  'data/cat_and_dogs/test\\10841.jpg',
#  'data/cat_and_dogs/test\\10842.jpg',
#  'data/cat_and_dogs/test\\10843.jpg',
#  'data/cat_and_dogs/test\\10844.jpg',
#  'data/cat_and_dogs/test\\10845.jpg',
#  'data/cat_and_dogs/test\\10846.jpg',
#  'data/cat_and_dogs/test\\10847.jpg',
#  'data/cat_and_dogs/test\\10848.jpg',
#  'data/cat_and_dogs/test\\10849.jpg',
#  'data/cat_and_dogs/test\\1085.jpg',
#  'data/cat_and_dogs/test\\10850.jpg',
#  'data/cat_and_dogs/test\\10851.jpg',
#  'data/cat_and_dogs/test\\10852.jpg',
#  'data/cat_and_dogs/test\\10853.jpg',
#  'data/cat_and_dogs/test\\10854.jpg',
#  'data/cat_and_dogs/test\\10855.jpg',
#  'data/cat_and_dogs/test\\10856.jpg',
#  'data/cat_and_dogs/test\\10857.jpg',
#  'data/cat_and_dogs/test\\10858.jpg',
#  'data/cat_and_dogs/test\\10859.jpg',
#  'data/cat_and_dogs/test\\1086.jpg',
#  'data/cat_and_dogs/test\\10860.jpg',
#  'data/cat_and_dogs/test\\10861.jpg',
#  'data/cat_and_dogs/test\\10862.jpg',
#  'data/cat_and_dogs/test\\10863.jpg',
#  'data/cat_and_dogs/test\\10864.jpg',
#  'data/cat_and_dogs/test\\10865.jpg',
#  'data/cat_and_dogs/test\\10866.jpg',
#  'data/cat_and_dogs/test\\10867.jpg',
#  'data/cat_and_dogs/test\\10868.jpg',
#  'data/cat_and_dogs/test\\10869.jpg',
#  'data/cat_and_dogs/test\\1087.jpg',
#  'data/cat_and_dogs/test\\10870.jpg',
#  'data/cat_and_dogs/test\\10871.jpg',
#  'data/cat_and_dogs/test\\10872.jpg',
#  'data/cat_and_dogs/test\\10873.jpg',
#  'data/cat_and_dogs/test\\10874.jpg',
#  'data/cat_and_dogs/test\\10875.jpg',
#  'data/cat_and_dogs/test\\10876.jpg',
#  'data/cat_and_dogs/test\\10877.jpg',
#  'data/cat_and_dogs/test\\10878.jpg',
#  'data/cat_and_dogs/test\\10879.jpg',
#  'data/cat_and_dogs/test\\1088.jpg',
#  'data/cat_and_dogs/test\\10880.jpg',
#  'data/cat_and_dogs/test\\10881.jpg',
#  'data/cat_and_dogs/test\\10882.jpg',
#  'data/cat_and_dogs/test\\10883.jpg',
#  'data/cat_and_dogs/test\\10884.jpg',
#  'data/cat_and_dogs/test\\10885.jpg',
#  'data/cat_and_dogs/test\\10886.jpg',
#  'data/cat_and_dogs/test\\10887.jpg',
#  'data/cat_and_dogs/test\\10888.jpg',
#  'data/cat_and_dogs/test\\10889.jpg',
#  'data/cat_and_dogs/test\\1089.jpg',
#  'data/cat_and_dogs/test\\10890.jpg',
#  'data/cat_and_dogs/test\\10891.jpg',
#  'data/cat_and_dogs/test\\10892.jpg',
#  'data/cat_and_dogs/test\\10893.jpg',
#  'data/cat_and_dogs/test\\10894.jpg',
#  'data/cat_and_dogs/test\\10895.jpg',
#  'data/cat_and_dogs/test\\10896.jpg',
#  'data/cat_and_dogs/test\\10897.jpg',
#  'data/cat_and_dogs/test\\10898.jpg',
#  ...]

# %%
len(test_files)
# Out:
# 12500

# %%
pred = model.predict_generator(predict_generator(test_files), len(test_files), max_queue_size=500)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-4279533d95f5> in <module>
# ----> 1 pred = model.predict_generator(predict_generator(test_files), len(test_files), max_queue_size=500)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    1534         workers=workers,
#    1535         use_multiprocessing=use_multiprocessing,
# -> 1536         verbose=verbose)
#    1537
#    1538   def _get_callback_model(self):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, **kwargs)
#     189       progbar.on_batch_begin(step, batch_logs)
#     190
# --> 191       batch_outs = batch_function(*batch_data)
#     192       if not isinstance(batch_outs, list):
#     193         batch_outs = [batch_outs]
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in predict_on_batch(x, y, sample_weights)
#     435     # 1, 2, or 3-tuples from generator
#     436     def predict_on_batch(x, y=None, sample_weights=None):  # pylint: disable=unused-argument
# --> 437       return model.predict_on_batch(x)
#     438
#     439     f = predict_on_batch
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict_on_batch(self, x)
#    1296
#    1297     self._make_predict_function()
# -> 1298     outputs = self.predict_function(inputs)
#    1299
#    1300     if len(outputs) == 1:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
for i, (path, score) in enumerate(zip(test_files[80:][:10], pred[80:][:10]), 1):
    subplot = fig.add_subplot(i // 5 + 1, 5, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%.3f' % score);

# %% [markdown]
# ## Готовим данные для сабмита

# %%
with open('submit.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, pred):
        dst.write('%s,%f\n' % (re.search('(\d+)', path).group(0), score))

# %%
# LogLoss = 1.04979
